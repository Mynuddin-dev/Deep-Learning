# %%
# Artificial Neural Network


# Part 1 - Data Preprocessing

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !wget https://github.com/krishnaik06/Complete-Deep-Learning/blob/master/ANN/Churn_Modelling.csv
# Out:
# --2022-07-05 13:51:43--  https://github.com/krishnaik06/Complete-Deep-Learning/blob/master/ANN/Churn_Modelling.csv
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Churn_Modelling.csv’
#
# Churn_Modelling.csv     [ <=>                ]   2.97M  --.-KB/s    in 0.09s
#
# 2022-07-05 13:51:43 (32.2 MB/s) - ‘Churn_Modelling.csv’ saved [3118453]

# %%
train = pd.read_csv("/content/Churn_Modelling.csv")

# %%
train
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

# %%
X
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

## Concatenate the Data Frames

X=pd.concat([X,geography,gender],axis=1)

## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# 1                  1        112542.58        0      1     0
# 2                  0        113931.57        0      0     0
# 3                  0         93826.63        0      0     0
# 4                  1         79084.10        0      1     0
# ...              ...              ...      ...    ...   ...
# 9995               0         96270.64        0      0     1
# 9996               1        101699.77        0      0     1
# 9997               1         42085.58        0      0     0
# 9998               0         92888.52        1      0     1
# 9999               0         38190.78        0      0     0
#
# [10000 rows x 11 columns]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 12, kernel_initializer = 'he_uniform',activation='relu', input_dim = 11))

# Adding the third hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_uniform',activation='relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10,epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.5006 - accuracy: 0.7918 - val_loss: 0.4607 - val_accuracy: 0.7997
# Epoch 2/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4405 - accuracy: 0.8044 - val_loss: 0.4405 - val_accuracy: 0.8058
# Epoch 3/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4221 - accuracy: 0.8186 - val_loss: 0.4300 - val_accuracy: 0.8114
# Epoch 4/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4099 - accuracy: 0.8248 - val_loss: 0.4196 - val_accuracy: 0.8152
# Epoch 5/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3977 - accuracy: 0.8367 - val_loss: 0.4073 - val_accuracy: 0.8232
# Epoch 6/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3829 - accuracy: 0.8431 - val_loss: 0.3951 - val_accuracy: 0.8277
# Epoch 7/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3696 - accuracy: 0.8498 - val_loss: 0.3844 - val_accuracy: 0.8379
# Epoch 8/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3584 - accuracy: 0.8528 - val_loss: 0.3767 - val_accuracy: 0.8406
# Epoch 9/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3510 - accuracy: 0.8556 - val_loss: 0.3725 - val_accuracy: 0.8410
# Epoch 10/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3465 - accuracy: 0.8582 - val_loss: 0.3706 - val_accuracy: 0.8417
# Epoch 11/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3435 - accuracy: 0.8584 - val_loss: 0.3699 - val_accuracy: 0.8440
# Epoch 12/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3410 - accuracy: 0.8580 - val_loss: 0.3711 - val_accuracy: 0.8440
# Epoch 13/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3399 - accuracy: 0.8582 - val_loss: 0.3694 - val_accuracy: 0.8444
# Epoch 14/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3381 - accuracy: 0.8608 - val_loss: 0.3689 - val_accuracy: 0.8451
# Epoch 15/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3372 - accuracy: 0.8587 - val_loss: 0.3691 - val_accuracy: 0.8448
# Epoch 16/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3366 - accuracy: 0.8591 - val_loss: 0.3684 - val_accuracy: 0.8474
# Epoch 17/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3353 - accuracy: 0.8617 - val_loss: 0.3674 - val_accuracy: 0.8463
# Epoch 18/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3349 - accuracy: 0.8615 - val_loss: 0.3673 - val_accuracy: 0.8463
# Epoch 19/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3346 - accuracy: 0.8612 - val_loss: 0.3692 - val_accuracy: 0.8459
# Epoch 20/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3338 - accuracy: 0.8621 - val_loss: 0.3696 - val_accuracy: 0.8493
# Epoch 21/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3335 - accuracy: 0.8615 - val_loss: 0.3696 - val_accuracy: 0.8451
# Epoch 22/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3329 - accuracy: 0.8614 - val_loss: 0.3676 - val_accuracy: 0.8497
# Epoch 23/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3323 - accuracy: 0.8610 - val_loss: 0.3668 - val_accuracy: 0.8482
# Epoch 24/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3318 - accuracy: 0.8625 - val_loss: 0.3662 - val_accuracy: 0.8478
# Epoch 25/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3310 - accuracy: 0.8614 - val_loss: 0.3667 - val_accuracy: 0.8482
# Epoch 26/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3301 - accuracy: 0.8632 - val_loss: 0.3686 - val_accuracy: 0.8478
# Epoch 27/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3304 - accuracy: 0.8628 - val_loss: 0.3673 - val_accuracy: 0.8508
# Epoch 28/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3302 - accuracy: 0.8627 - val_loss: 0.3656 - val_accuracy: 0.8489
# Epoch 29/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3297 - accuracy: 0.8627 - val_loss: 0.3664 - val_accuracy: 0.8489
# Epoch 30/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3287 - accuracy: 0.8638 - val_loss: 0.3649 - val_accuracy: 0.8489
# Epoch 31/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3285 - accuracy: 0.8653 - val_loss: 0.3667 - val_accuracy: 0.8485
# Epoch 32/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3284 - accuracy: 0.8625 - val_loss: 0.3648 - val_accuracy: 0.8504
# Epoch 33/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3275 - accuracy: 0.8623 - val_loss: 0.3650 - val_accuracy: 0.8497
# Epoch 34/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3274 - accuracy: 0.8647 - val_loss: 0.3658 - val_accuracy: 0.8508
# Epoch 35/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3266 - accuracy: 0.8656 - val_loss: 0.3660 - val_accuracy: 0.8493
# Epoch 36/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3266 - accuracy: 0.8636 - val_loss: 0.3683 - val_accuracy: 0.8497
# Epoch 37/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3263 - accuracy: 0.8632 - val_loss: 0.3664 - val_accuracy: 0.8493
# Epoch 38/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3251 - accuracy: 0.8653 - val_loss: 0.3675 - val_accuracy: 0.8512
# Epoch 39/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3257 - accuracy: 0.8638 - val_loss: 0.3666 - val_accuracy: 0.8504
# Epoch 40/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3258 - accuracy: 0.8653 - val_loss: 0.3687 - val_accuracy: 0.8497
# Epoch 41/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3257 - accuracy: 0.8632 - val_loss: 0.3671 - val_accuracy: 0.8504
# Epoch 42/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3252 - accuracy: 0.8627 - val_loss: 0.3688 - val_accuracy: 0.8474
# Epoch 43/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3248 - accuracy: 0.8632 - val_loss: 0.3667 - val_accuracy: 0.8504
# Epoch 44/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3251 - accuracy: 0.8628 - val_loss: 0.3686 - val_accuracy: 0.8478
# Epoch 45/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3246 - accuracy: 0.8642 - val_loss: 0.3681 - val_accuracy: 0.8474
# Epoch 46/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3248 - accuracy: 0.8649 - val_loss: 0.3686 - val_accuracy: 0.8489
# Epoch 47/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3239 - accuracy: 0.8645 - val_loss: 0.3684 - val_accuracy: 0.8466
# Epoch 48/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3237 - accuracy: 0.8638 - val_loss: 0.3688 - val_accuracy: 0.8504
# Epoch 49/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3235 - accuracy: 0.8640 - val_loss: 0.3699 - val_accuracy: 0.8493
# Epoch 50/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3233 - accuracy: 0.8627 - val_loss: 0.3664 - val_accuracy: 0.8482
# Epoch 51/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3231 - accuracy: 0.8634 - val_loss: 0.3698 - val_accuracy: 0.8459
# Epoch 52/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3233 - accuracy: 0.8651 - val_loss: 0.3687 - val_accuracy: 0.8493
# Epoch 53/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3221 - accuracy: 0.8647 - val_loss: 0.3697 - val_accuracy: 0.8504
# Epoch 54/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3229 - accuracy: 0.8655 - val_loss: 0.3680 - val_accuracy: 0.8474
# Epoch 55/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3225 - accuracy: 0.8655 - val_loss: 0.3687 - val_accuracy: 0.8493
# Epoch 56/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3221 - accuracy: 0.8653 - val_loss: 0.3696 - val_accuracy: 0.8504
# Epoch 57/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3224 - accuracy: 0.8658 - val_loss: 0.3684 - val_accuracy: 0.8485
# Epoch 58/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3217 - accuracy: 0.8653 - val_loss: 0.3713 - val_accuracy: 0.8516
# Epoch 59/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3221 - accuracy: 0.8638 - val_loss: 0.3685 - val_accuracy: 0.8497
# Epoch 60/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3212 - accuracy: 0.8645 - val_loss: 0.3682 - val_accuracy: 0.8497
# Epoch 61/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3213 - accuracy: 0.8642 - val_loss: 0.3681 - val_accuracy: 0.8485
# Epoch 62/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3213 - accuracy: 0.8675 - val_loss: 0.3700 - val_accuracy: 0.8504
# Epoch 63/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3208 - accuracy: 0.8673 - val_loss: 0.3688 - val_accuracy: 0.8508
# Epoch 64/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3205 - accuracy: 0.8673 - val_loss: 0.3692 - val_accuracy: 0.8485
# Epoch 65/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3207 - accuracy: 0.8662 - val_loss: 0.3679 - val_accuracy: 0.8493
# Epoch 66/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3210 - accuracy: 0.8664 - val_loss: 0.3706 - val_accuracy: 0.8501
# Epoch 67/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3203 - accuracy: 0.8658 - val_loss: 0.3688 - val_accuracy: 0.8478
# Epoch 68/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3197 - accuracy: 0.8658 - val_loss: 0.3706 - val_accuracy: 0.8497
# Epoch 69/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3199 - accuracy: 0.8664 - val_loss: 0.3713 - val_accuracy: 0.8508
# Epoch 70/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3194 - accuracy: 0.8671 - val_loss: 0.3687 - val_accuracy: 0.8485
# Epoch 71/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3198 - accuracy: 0.8666 - val_loss: 0.3691 - val_accuracy: 0.8516
# Epoch 72/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3194 - accuracy: 0.8671 - val_loss: 0.3686 - val_accuracy: 0.8482
# Epoch 73/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3190 - accuracy: 0.8668 - val_loss: 0.3708 - val_accuracy: 0.8508
# Epoch 74/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3190 - accuracy: 0.8671 - val_loss: 0.3693 - val_accuracy: 0.8504
# Epoch 75/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3187 - accuracy: 0.8664 - val_loss: 0.3698 - val_accuracy: 0.8504
# Epoch 76/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3188 - accuracy: 0.8662 - val_loss: 0.3707 - val_accuracy: 0.8504
# Epoch 77/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3184 - accuracy: 0.8686 - val_loss: 0.3702 - val_accuracy: 0.8501
# Epoch 78/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3181 - accuracy: 0.8666 - val_loss: 0.3690 - val_accuracy: 0.8489
# Epoch 79/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3186 - accuracy: 0.8675 - val_loss: 0.3694 - val_accuracy: 0.8519
# Epoch 80/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3179 - accuracy: 0.8675 - val_loss: 0.3736 - val_accuracy: 0.8470
# Epoch 81/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3181 - accuracy: 0.8675 - val_loss: 0.3727 - val_accuracy: 0.8501
# Epoch 82/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3173 - accuracy: 0.8684 - val_loss: 0.3723 - val_accuracy: 0.8474
# Epoch 83/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3176 - accuracy: 0.8677 - val_loss: 0.3715 - val_accuracy: 0.8478
# Epoch 84/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3173 - accuracy: 0.8696 - val_loss: 0.3717 - val_accuracy: 0.8466
# Epoch 85/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3171 - accuracy: 0.8692 - val_loss: 0.3726 - val_accuracy: 0.8478
# Epoch 86/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3175 - accuracy: 0.8666 - val_loss: 0.3713 - val_accuracy: 0.8489
# Epoch 87/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3167 - accuracy: 0.8673 - val_loss: 0.3754 - val_accuracy: 0.8482
# Epoch 88/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3174 - accuracy: 0.8679 - val_loss: 0.3728 - val_accuracy: 0.8497
# Epoch 89/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3165 - accuracy: 0.8683 - val_loss: 0.3727 - val_accuracy: 0.8493
# Epoch 90/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3171 - accuracy: 0.8666 - val_loss: 0.3710 - val_accuracy: 0.8485
# Epoch 91/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3171 - accuracy: 0.8694 - val_loss: 0.3735 - val_accuracy: 0.8485
# Epoch 92/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3164 - accuracy: 0.8658 - val_loss: 0.3745 - val_accuracy: 0.8497
# Epoch 93/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3163 - accuracy: 0.8681 - val_loss: 0.3724 - val_accuracy: 0.8497
# Epoch 94/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3165 - accuracy: 0.8681 - val_loss: 0.3736 - val_accuracy: 0.8485
# Epoch 95/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3158 - accuracy: 0.8696 - val_loss: 0.3754 - val_accuracy: 0.8504
# Epoch 96/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3158 - accuracy: 0.8670 - val_loss: 0.3741 - val_accuracy: 0.8493
# Epoch 97/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3170 - accuracy: 0.8651 - val_loss: 0.3723 - val_accuracy: 0.8493
# Epoch 98/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3159 - accuracy: 0.8679 - val_loss: 0.3729 - val_accuracy: 0.8489
# Epoch 99/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3154 - accuracy: 0.8677 - val_loss: 0.3742 - val_accuracy: 0.8489
# Epoch 100/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3155 - accuracy: 0.8681 - val_loss: 0.3748 - val_accuracy: 0.8508

# %%
# list all data in history

print(model_history.history.keys())
# summarize history for accuracy
plt.figure(figsize=(12,8))
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for loss
plt.figure(figsize=(12,8))
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([[0.33923423],
#        [0.22731233],
#        [0.222334  ],
#        ...,
#        [0.17549324],
#        [0.13746586],
#        [0.3288337 ]], dtype=float32)

# %%
y_pred = (y_pred > 0.5)
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)

# %%
print(score)
print(cm)
# Out:
# 0.8615
# [[1538   57]
#  [ 220  185]]
